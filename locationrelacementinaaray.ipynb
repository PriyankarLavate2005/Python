# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyankarLavate2005/Python/blob/main/locationrelacementinaaray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
arr = [7, 6, 4, 8, 3, 5]
i = 0
n = len(arr) - 1

while i < n:
    arr[i], arr[n] = arr[n], arr[i]  # Swap elements
    i += 1
    n -= 1

print(arr)
# Out:
# [5, 3, 8, 4, 6, 7]
