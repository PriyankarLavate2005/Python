# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyankarLavate2005/Python/blob/main/bil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t=int(input())
for _ in range(t):
    x=int(input())
    if x*0.10 > 100:
        print(int(x*0.10))
    else:
        print(100)
# Out:
# 300
# 30.0

# %%
# cook your dish here
t=int(input())
for _ in range(t):
    x=int(input())
    y=int(input())
    diff=x-y
    if diff>y:
        print(diff-y)
    else:
        print(y-diff)
# Out:
# 2
# 100
# 90
# 80
# 40
# 10
# 20
