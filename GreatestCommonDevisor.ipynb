# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyankarLavate2005/Python/blob/main/GreatestCommonDevisor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=int(input("enter the number"))
num2=int(input("enter second number"))
if num1>num2:
  num=num1
else:
  num=num2
for i in range(1,num+1):
  if num%i==0:
    hcf=i
print("HCF:",hcf)
# Out:
# enter the number78
# enter second number78
# HCF: 78
